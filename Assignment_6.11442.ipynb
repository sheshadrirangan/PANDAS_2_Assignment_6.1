# %% [markdown]
# ## Assignment_6.11442

# %% [markdown]
# ### Read the dataset from the below link
#
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US _Baby_Names/US_Baby_Names_right.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %% [markdown]
# ### 1. Delete unnamed columns

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'Id', 'Name', 'Year', 'Gender', 'State', 'Count'],
#       dtype=object)

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)
df.head()
# Out:
#       Id     Name  Year Gender State  Count
# 0  11350     Emma  2004      F    AK     62
# 1  11351  Madison  2004      F    AK     48
# 2  11352   Hannah  2004      F    AK     46
# 3  11353    Grace  2004      F    AK     44
# 4  11354    Emily  2004      F    AK     41

# %% [markdown]
# ### 2. Show the distribution of male and female

# %%
df.groupby('Gender').Count.describe()
# Out:
#            count       mean         std  min  25%   50%   75%     max
# Gender
# F       558846.0  29.310925   75.962992  5.0  6.0  10.0  23.0  3634.0
# M       457549.0  41.615650  118.074308  5.0  7.0  12.0  29.0  4167.0

# %%
df.groupby('Gender').Gender.count()
# Out:
# Gender
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %% [markdown]
# ### 3. Show the top 5 most preferred names

# %%
a = df.groupby('Name').sum().sort_values(by=['Count'], ascending=False)
b = a.Count.sort_values(ascending=False)
a.head()
# Out:
#                   Id     Year   Count
# Name
# Jacob     1665681356  1141099  242874
# Emma      1629482250  1137085  214852
# Michael   1687521295  1161152  214405
# Ethan     1660808475  1139091  209277
# Isabella  1630131786  1137090  204798

# %%
g = df.groupby("Name").sum().sort_values(by=['Count'], ascending=False)
g.head()
# Out:
#                   Id     Year   Count
# Name
# Jacob     1665681356  1141099  242874
# Emma      1629482250  1137085  214852
# Michael   1687521295  1161152  214405
# Ethan     1660808475  1139091  209277
# Isabella  1630131786  1137090  204798

# %%
b = df.groupby('Name')
b.Count.sum().sort_values(ascending=False).head()
# Out:
# Name
# Jacob       242874
# Emma        214852
# Michael     214405
# Ethan       209277
# Isabella    204798
# Name: Count, dtype: int64

# %% [markdown]
# ### 4. What is the median name occurence in the dataset

# %%
df.median()
# Out:
# Id       2811921.0
# Year        2009.0
# Count         11.0
# dtype: float64

# %%
df.iloc[df.reset_index().median()['index'].astype(int)]
# Out:
# Id        2811921
# Name        Kasey
# Year         2010
# Gender          F
# State          MO
# Count           6
# Name: 508197, dtype: object

# %%
df.iloc[df.reset_index().median()['index'].astype(int)].Name
# Out:
# 'Kasey'

# %%
df.loc[df.Id == df.Id.median()]
# Out:
#              Id   Name  Year Gender State  Count
# 508197  2811921  Kasey  2010      F    MO      6

# %%
df.Name.loc[df.Id == df.Id.median()]
# Out:
# 508197    Kasey
# Name: Name, dtype: object

# %%
df.loc[df.Id == df.Id.median()].Name
# Out:
# 508197    Kasey
# Name: Name, dtype: object

# %% [markdown]
# ### 5. Distribution of male and female born count by states

# %%
df.groupby(['State','Gender']).describe()
# Out:
#                 Count                                                       \
#                 count       mean         std  min  25%   50%   75%     max
# State Gender
# AK    F        2404.0  10.919301    8.159519  5.0  6.0   8.0  13.0    62.0
#       M        2587.0  14.456513   11.295679  5.0  6.0  10.0  19.0    67.0
# AL    F        9878.0  21.796720   34.348342  5.0  6.0  10.0  21.0   403.0
#       M        8419.0  30.896068   52.796016  5.0  7.0  12.0  27.0   639.0
# AR    F        7171.0  18.088412   23.925343  5.0  6.0  10.0  19.0   281.0
#       M        6475.0  25.165560   33.510502  5.0  7.0  11.0  27.0   270.0
# AZ    F       14518.0  25.386899   43.385838  5.0  7.0  11.0  23.0   604.0
#       M       10820.0  40.636876   72.904882  5.0  7.0  12.0  37.0   656.0
# CA    F       45144.0  53.474725  164.342504  5.0  7.0  12.0  32.0  3634.0
#       M       31637.0  84.413314  281.483774  5.0  7.0  12.0  35.0  4167.0
# ...

# %%
df.groupby(['State','Gender']).describe().Count
# Out:
#                 count       mean         std  min  25%   50%   75%     max
# State Gender
# AK    F        2404.0  10.919301    8.159519  5.0  6.0   8.0  13.0    62.0
#       M        2587.0  14.456513   11.295679  5.0  6.0  10.0  19.0    67.0
# AL    F        9878.0  21.796720   34.348342  5.0  6.0  10.0  21.0   403.0
#       M        8419.0  30.896068   52.796016  5.0  7.0  12.0  27.0   639.0
# AR    F        7171.0  18.088412   23.925343  5.0  6.0  10.0  19.0   281.0
#       M        6475.0  25.165560   33.510502  5.0  7.0  11.0  27.0   270.0
# AZ    F       14518.0  25.386899   43.385838  5.0  7.0  11.0  23.0   604.0
#       M       10820.0  40.636876   72.904882  5.0  7.0  12.0  37.0   656.0
# CA    F       45144.0  53.474725  164.342504  5.0  7.0  12.0  32.0  3634.0
#       M       31637.0  84.413314  281.483774  5.0  7.0  12.0  35.0  4167.0
# CO    F       11424.0  22.829569   34.731560  5.0  6.0  10.0  23.0   349.0
# ...

# %%
df.groupby(['State','Gender']).describe().Count['count']
# Out:
# State  Gender
# AK     F          2404.0
#        M          2587.0
# AL     F          9878.0
#        M          8419.0
# AR     F          7171.0
#        M          6475.0
# AZ     F         14518.0
#        M         10820.0
# CA     F         45144.0
#        M         31637.0
# CO     F         11424.0
#        M          9183.0
# CT     F          6575.0
#        M          5733.0
# DC     F          3053.0
#        M          3000.0
# DE     F          2549.0
#        M          2440.0
# FL     F         25781.0
#        M         20070.0
# GA     F         19385.0
#        M         15454.0
# HI     F          3255.0
#        M          3546.0
# IA     F          7131.0
#        M          6307.0
# ID     F          4918.0
#        M          4833.0
# IL     F         21268.0
#        M         16828.0
#                   ...
# OK     F          9519.0
#        M          8138.0
# OR     F          8604.0
#        M          7333.0
# PA     F         17480.0
# ...

# %%
s = df.groupby(['State','Gender']).sum()
s.Count
# Out:
# State  Gender
# AK     F           26250
#        M           37399
# AL     F          215308
#        M          260114
# AR     F          129712
#        M          162947
# AZ     F          368567
#        M          439691
# CA     F         2414063
#        M         2670584
# CO     F          260805
#        M          313425
# CT     F          141350
#        M          171397
# DC     F           35276
#        M           47228
# DE     F           31312
#        M           41748
# FL     F          915422
#        M         1060957
# GA     F          549637
#        M          635531
# HI     F           37279
#        M           53127
# IA     F          144764
#        M          174009
# ID     F           72808
#        M           94320
# IL     F          695312
#        M          791679
#                   ...
# OK     F          184967
#        M          228613
# OR     F          172111
#        M          209445
# PA     F          593382
# ...
